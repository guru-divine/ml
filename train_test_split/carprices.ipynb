# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
model = pd.read_csv("carprices.csv")
model
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
X = model[['Mileage', 'Age(yrs)']]
y = model['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([39320.5017848 , 35152.78314517, 17995.67731077, 22719.09112766,
#        28744.91701944])

# %%
reg.score(X_test, y_test)
# Out:
# 0.8804228097475002

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(model[['Mileage']], model[['Sell Price($)']], marker='+')

# %%
plt.scatter(model[['Age(yrs)']], model[['Sell Price($)']], marker='+')
